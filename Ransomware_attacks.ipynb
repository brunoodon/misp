# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoodon/misp/blob/main/Ransomware_attacks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import numpy as np
url_ransomware_attacks = "https://mvp-puc.brunoodon.com.br/datasets/ransomware_attacks.csv"
#r_url_android_ransomware = requests.get(url_android_ransomware)
#print(r_url_android_ransomware.text)
ransomware_attacks_data = pd.read_csv(url_ransomware_attacks, sep=';')
ransomware_attacks_data.head(50)
# Out:
#                       Target                                          AKA  \
# 0              display label                                          NaN
# 1                     Kaseya                                          NaN
# 2             Salvation Army                                          NaN
# 3               Grupo Fleury                                          NaN
# 4              City of Liege                                          NaN
# 5          Lucky Star Casino                                          NaN
# 6                       MRWD             Mountain Regional Water District
# 7                        RBA              Reproductive Biology Associates
# 8                 Judson ISD                                          NaN
# 9      Humber River Hospital                                          NaN
# 10                     DMACC            Des Moines Area Community College
# 11          Town of Freeport                                          NaN
# ...
